# %%
import pandas as pd

# %%
df = pd.read_csv("./../data/df.csv")

# %%
df
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0                 1364  26984896261    1      842930         1         2.19
# 1                 1364  26984896261    1      897044         1         2.99
# 2                 1364  26984896261    1      920955         1         3.09
# 3                 1364  26984896261    1      937406         1         2.50
# 4                 1364  26984896261    1      981760         1         0.60
# ...                ...          ...  ...         ...       ...          ...
# 1427298           1369  42302712189  711      844054         1         1.29
# 1427299           1369  42302712189  711      844759         1         1.69
# 1427300           1369  42302712189  711      959737         2        25.98
# 1427301           1369  42302712189  711     1135096         1         1.99
# 1427302           1369  42302712189  711     9526344         1         2.69
#
# ...

# %%
df[df["PRODUCT_ID"] == 842930][["SALES_VALUE", "QUANTITY"]]
# Out:
#          SALES_VALUE  QUANTITY
# 0               2.19         1
# 9131            3.34         2
# 25965           1.67         1
# 45108           1.67         1
# 46957           3.33         2
# ...              ...       ...
# 1400506         1.67         1
# 1401600         1.67         1
# 1402257         2.12         1
# 1406901         1.67         1
# 1425255         2.12         1
#
# [114 rows x 2 columns]

# %%
campaign_desc = pd.read_csv("./../data/campaign_desc.csv")

# %%
campaign_desc["START_DAY"].max()
# Out:
# 659
